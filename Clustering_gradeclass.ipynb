# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
data=pd.read_excel("DATA-FINAL.xls")

# %%
data.head()
# Out:
#    Termid  Regd No  Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 0  318192  1101776    KVY1     O    87.0    39.0     82.0     89.0
# 1  318192  1101776  KVY147    A+    87.0    47.0     65.0     85.0
# 2  318192  1101776  KVY148    B+    84.0    29.0     63.0     77.0
# 3  318192  1101776    KVY2    A+     NaN     NaN      NaN     82.0
# 4  318192  1101776    KVY3    A+    87.0    34.0     68.0     89.0
#
#    Course_Att                                     MHRDName  CA_1  CA_2  CA_3  \
# 0        88.0  Bachelor of Science (Honours) (Agriculture)  41.0  45.0   1.0
# 1        82.0  Bachelor of Science (Honours) (Agriculture)  86.0   0.0   0.0
# 2        76.0  Bachelor of Science (Honours) (Agriculture)  76.0   0.0   3.0
# 3        74.0  Bachelor of Science (Honours) (Agriculture)   NaN   NaN   NaN
# 4        76.0  Bachelor of Science (Honours) (Agriculture)  42.0  26.0   2.0
#
#    CA_4  Height  Weight ScholarType Direction  Gender Medium CourseType  \
# ...

# %%
data2=data[data['MHRDName']=="Bachelor of Technology (Biomedical Engineering)"]

# %%
data2
# Out:
#        Termid   Regd No  Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 1561   218192   1541776   LQZ20    A+    95.0    25.0     73.0      NaN
# 1562   218192   1541776   LQZ28     A    60.0    37.0     73.0      NaN
# 1563   218192   1541776  LQZ651     O    85.0     NaN      NaN     94.0
# 1564   218192   1541776  LQZ652     O    89.0    44.0     88.0      NaN
# 1565   218192   1541776  LQZ653     O    99.0    48.0     92.0      NaN
# ...       ...       ...     ...   ...     ...     ...      ...      ...
# 62295  118192  14877776  LQZ313     A    75.0     NaN      NaN     81.0
# 62296  118192  14877776  LQZ385    A+    78.0    24.0     70.0      NaN
# 62297  118192  14877776  LQZ452     A    74.0    28.0     59.0      NaN
# 62298  118192  14877776  LQZ861     O    89.0    42.0     89.0      NaN
# 62299  118192  14877776  LQZ862     B    62.0    19.0     46.0      NaN
#
#        Course_Att                                         MHRDName  CA_1  \
# ...

# %%
print(data2.Gender.value_counts())
# Out:
# Female    64
# Male      29
# Name: Gender, dtype: int64

# %%
print("Original features:\n", list(data2.columns), "\n")
data_dummies = pd.get_dummies(data2)
print("Features after get_dummies:\n", list(data_dummies.columns))
# Out:
# Original features:
#  ['Termid', 'Regd No', 'Course', 'Grade', 'CA_100', 'MTT_50', 'ETT_100', 'ETP_100', 'Course_Att', 'MHRDName', 'CA_1', 'CA_2', 'CA_3', 'CA_4', 'Height', 'Weight', 'ScholarType', 'Direction', 'Gender', 'Medium', 'CourseType', 'ProgramType']
#
# Features after get_dummies:
# ...

# %%
data_dummies.head()
# Out:
#       Termid  Regd No  CA_100  MTT_50  ETT_100  ETP_100  Course_Att  CA_1  \
# 1561  218192  1541776    95.0    25.0     73.0      NaN        96.0  19.0
# 1562  218192  1541776    60.0    37.0     73.0      NaN        94.0  47.0
# 1563  218192  1541776    85.0     NaN      NaN     94.0       100.0  21.0
# 1564  218192  1541776    89.0    44.0     88.0      NaN        96.0  73.0
# 1565  218192  1541776    99.0    48.0     92.0      NaN       100.0  78.0
#
#       CA_2  CA_3  CA_4  Height  Weight  Course_LQZ1680  Course_LQZ20  \
# 1561   1.0  39.0  36.0     162      48               0             1
# 1562  12.0   1.0   0.0     162      48               0             0
# 1563  20.0  13.0  31.0     162      48               0             0
# 1564  13.0   0.0   3.0     162      48               0             0
# 1565  19.0   2.0   0.0     162      48               0             0
#
#       Course_LQZ28  Course_LQZ310  Course_LQZ311  Course_LQZ312  \
# ...

# %%
half_count = len(data2) / 2
data2 = data2.dropna(thresh=half_count,axis=1) # Drop any column with more than 50% missing values
data2 = data2.drop(['Termid','Course','Height','Weight','ScholarType','Direction','ProgramType'],axis=1)

# %%
data2.head()
# Out:
#       Regd No Grade  CA_100  MTT_50  ETT_100  Course_Att  \
# 1561  1541776    A+    95.0    25.0     73.0        96.0
# 1562  1541776     A    60.0    37.0     73.0        94.0
# 1563  1541776     O    85.0     NaN      NaN       100.0
# 1564  1541776     O    89.0    44.0     88.0        96.0
# 1565  1541776     O    99.0    48.0     92.0       100.0
#
#                                              MHRDName  CA_1  CA_2  CA_3  CA_4  \
# 1561  Bachelor of Technology (Biomedical Engineering)  19.0   1.0  39.0  36.0
# 1562  Bachelor of Technology (Biomedical Engineering)  47.0  12.0   1.0   0.0
# 1563  Bachelor of Technology (Biomedical Engineering)  21.0  20.0  13.0  31.0
# 1564  Bachelor of Technology (Biomedical Engineering)  73.0  13.0   0.0   3.0
# 1565  Bachelor of Technology (Biomedical Engineering)  78.0  19.0   2.0   0.0
#
#       Gender   Medium CourseType
# 1561  Female  English     Theory
# 1562  Female  English     Theory
# 1563  Female  English     Theory
# ...

# %%
data2.tail()
# Out:
#         Regd No Grade  CA_100  MTT_50  ETT_100  Course_Att  \
# 62295  14877776     A    75.0     NaN      NaN        95.0
# 62296  14877776    A+    78.0    24.0     70.0        93.0
# 62297  14877776     A    74.0    28.0     59.0        90.0
# 62298  14877776     O    89.0    42.0     89.0       100.0
# 62299  14877776     B    62.0    19.0     46.0        96.0
#
#                                               MHRDName  CA_1  CA_2  CA_3  \
# 62295  Bachelor of Technology (Biomedical Engineering)   8.0   3.0   8.0
# 62296  Bachelor of Technology (Biomedical Engineering)  32.0  39.0   6.0
# 62297  Bachelor of Technology (Biomedical Engineering)  31.0  16.0  25.0
# 62298  Bachelor of Technology (Biomedical Engineering)  47.0   3.0  39.0
# 62299  Bachelor of Technology (Biomedical Engineering)  30.0  28.0   4.0
#
#        CA_4 Gender Medium CourseType
# 62295  56.0   Male  Hindi     Theory
# 62296   1.0   Male  Hindi     Theory
# 62297   2.0   Male  Hindi     Theory
# ...

# %%
data2.shape
# Out:
# (93, 14)

# %%
print(data2['CA_100'].unique())
print(data2['MTT_50'].unique())
print(data2['ETT_100'].unique())
# Out:
# [95. 60. 85. 89. 99. 84. 92. 94. 82. 75. 45. 62. 58. 87. 69. 74. 57. 72.
#  71. 67. 77. 66. 90. 37.  0. 70. 64. 65. 86. 80. 17. 68. 44. 83. 79. 81.
#  12. 59. 88. 78. 56. 47. 25. 97.]
# [25. 37. nan 44. 48. 45. 47. 32. 19. 28. 38. 40. 35. 22. 27. 34. 39.  0.
#  23. 30. 20. 24.  9. 29. 42. 43. 17. 33.]
# [73. nan 88. 92. 89. 96. 93. 18. 60. 76. 62. 82. 22. 41. 70. 69. 80. 83.
#  72.  0. 55. 50. 66. 36. 39. 86. 45. 42. 75. 90. 28.  9. 85. 63. 79. 59.
#  46.]

# %%
Marks_columns = ['CA_100','MTT_50','ETT_100']
print(data2.shape[0])
data2.dropna(subset=Marks_columns,inplace=True)
print(data2.shape[0])
data2[Marks_columns].plot.hist(alpha=0.5,bins=20);
# Out:
# 93
# 63

# %%
data2['Marks_average'] = (data2['CA_100'] + data2['MTT_50'] + data2['ETT_100']) / 3
cols = ['CA_100','MTT_50','ETT_100','Marks_average']
data2[cols].head()
# Out:
#       CA_100  MTT_50  ETT_100  Marks_average
# 1561    95.0    25.0     73.0      64.333333
# 1562    60.0    37.0     73.0      56.666667
# 1564    89.0    44.0     88.0      73.666667
# 1565    99.0    48.0     92.0      79.666667
# 1567    92.0    48.0     89.0      76.333333

# %%
print(data2['CA_1'].unique())
print(data2['CA_2'].unique())
print(data2['CA_3'].unique())
print(data2['CA_4'].unique())
# Out:
# [19. 47. 73. 78.  0. 34. 63. 24. 42. 23. 29. 43. 65. 14. 27. 45. 30. 77.
#  17. 28. 16. 56. 15. 21. 57. 35.  6. 40. 55. 48.  4. 11. 31.  1. 12. 49.
#  70. 53. 25. 33. 68. 22. 87. 26. 32.]
# [ 1. 12. 13. 19.  0. 29.  5.  2. 15. 21. 42. 27.  8. 22.  3. 37. 50.  7.
#  11. 24. 68. 17. 61. 43. 41. 47. 39. 34.  6. 25. 35. 16. 28.]
# [39.  1.  0.  2. 12. 21. 14. 17.  6.  3.  5.  9. 11. 38.  8.  4. 16. 25.]
# [36.  0.  3. 80. 10.  2.  5. 32. 13.  9. 11. 16.  7. 23. 44.  4.  8. 15.
#   1.  6. 28. 26. 18. 17.]

# %%
drop_cols = ['CA_100','MTT_50','ETT_100', 'CourseType','MHRDName']
data2 = data2.drop(drop_cols, axis=1)
data2.shape
# Out:
# (63, 10)

# %%
data2.head()
# Out:
#       Regd No Grade  Course_Att  CA_1  CA_2  CA_3  CA_4  Gender   Medium  \
# 1561  1541776    A+        96.0  19.0   1.0  39.0  36.0  Female  English
# 1562  1541776     A        94.0  47.0  12.0   1.0   0.0  Female  English
# 1564  1541776     O        96.0  73.0  13.0   0.0   3.0  Female  English
# 1565  1541776     O       100.0  78.0  19.0   2.0   0.0  Female  English
# 1567  1541776     O        95.0   0.0   0.0  12.0  80.0  Female  English
#
#       Marks_average
# 1561      64.333333
# 1562      56.666667
# 1564      73.666667
# 1565      79.666667
# 1567      76.333333

# %%
data2['CA_average'] = (data2['CA_1'] + data2['CA_2'] + data2['CA_3'] + data2['CA_4']) / 4
cols = ['CA_1','CA_2','CA_3','CA_4','CA_average']
data2[cols].head()
# Out:
#       CA_1  CA_2  CA_3  CA_4  CA_average
# 1561  19.0   1.0  39.0  36.0       23.75
# 1562  47.0  12.0   1.0   0.0       15.00
# 1564  73.0  13.0   0.0   3.0       22.25
# 1565  78.0  19.0   2.0   0.0       24.75
# 1567   0.0   0.0  12.0  80.0       23.00

# %%
drop_cols = ['CA_1','CA_2','CA_3', 'CA_4','Regd No']
data2 = data2.drop(drop_cols, axis=1)
data2.shape
# Out:
# (63, 6)

# %%
null_counts = data2.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# Grade            0
# Course_Att       0
# Gender           0
# Medium           0
# Marks_average    0
# CA_average       0
# dtype: int64

# %%
print("Data types and their frequency\n{}".format(data2.dtypes.value_counts()))
# Out:
# Data types and their frequency
# object     3
# float64    3
# dtype: int64

# %%
object_columns_df = data2.select_dtypes(include=['object'])
print(object_columns_df.iloc[0])
# Out:
# Grade          A+
# Gender     Female
# Medium    English
# Name: 1561, dtype: object

# %%
cols = ['Grade','Gender', 'Medium']
for name in cols:
    print(name,':')
    print(object_columns_df[name].value_counts(),'\n')
# Out:
# Grade :
# B+    12
# A     12
# A+    10
# E      7
# B      6
# O      6
# F      5
# C      4
# D      1
# Name: Grade, dtype: int64
#
# Gender :
# Female    42
# Male      21
# Name: Gender, dtype: int64
#
# Medium :
# English     28
# Regional    21
# Hindi       14
# Name: Medium, dtype: int64

# %%
mapping_dict = {
"Gender": {
"Male": 0,
"Female": 1
},
"Grade":{
"O": 1,
"A": 2,
"A+": 3,
"B": 4,
"B+": 5,
"C": 6,
"D": 7,
"E": 8,
"F": 9
},
"Medium":{
"English": 0,
"Regional": 1,
"Hindi": 2
}
}
data2 = data2.replace(mapping_dict)
data2[['Gender','Grade','Medium']].head()
# Out:
#       Gender  Grade  Medium
# 1561       1      3       0
# 1562       1      2       0
# 1564       1      1       0
# 1565       1      1       0
# 1567       1      1       0

# %%
data2
# Out:
#        Grade  Course_Att  Gender  Medium  Marks_average  CA_average
# 1561       3        96.0       1       0      64.333333       23.75
# 1562       2        94.0       1       0      56.666667       15.00
# 1564       1        96.0       1       0      73.666667       22.25
# 1565       1       100.0       1       0      79.666667       24.75
# 1567       1        95.0       1       0      76.333333       23.00
# ...      ...         ...     ...     ...            ...         ...
# 62294      2        97.0       0       2      61.000000       18.75
# 62296      3        93.0       0       2      57.333333       19.50
# 62297      2        90.0       0       2      53.666667       18.50
# 62298      1       100.0       0       2      73.333333       22.25
# 62299      4        96.0       0       2      42.333333       15.50
#
# [63 rows x 6 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 1561 to 62299
# Data columns (total 6 columns):
# Grade            63 non-null int64
# Course_Att       63 non-null float64
# Gender           63 non-null int64
# Medium           63 non-null int64
# Marks_average    63 non-null float64
# CA_average       63 non-null float64
# dtypes: float64(3), int64(3)
# memory usage: 3.4 KB

# %%
from sklearn.cluster import KMeans
x = data2.iloc[:, [0,1]].values

# %%
kmeans5 = KMeans(n_clusters=5)
y_kmeans5 = kmeans5.fit_predict(x)
print(y_kmeans5)

kmeans5.cluster_centers_
# Out:
# [0 0 0 0 0 0 0 3 3 3 3 2 1 3 3 3 3 3 3 3 3 4 1 4 1 4 4 4 0 2 1 3 0 1 1 1 1
#  2 1 3 3 2 1 2 1 3 3 1 1 3 1 3 1 1 0 3 0 3 0 0 3 0 0]
# array([[ 2.46666667, 95.86666667],
#        [ 5.1875    , 77.4375    ],
#        [ 5.        , 53.4       ],
#        [ 3.90909091, 87.13636364],
#        [ 9.        , 65.4       ]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
print(y_kmeans3)
# Out:
# [0 0 0 0 0 0 0 2 0 2 2 1 2 2 0 0 2 0 2 0 0 1 2 1 2 1 1 1 0 1 2 0 0 2 2 2 2
#  1 2 0 2 1 2 1 2 0 2 2 2 0 2 2 2 2 0 2 0 2 0 0 0 0 0]

# %%
kmeans3.cluster_centers_
# Out:
# array([[ 3.03846154, 93.15384615],
#        [ 7.        , 59.4       ],
#        [ 4.7037037 , 80.44444444]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x[:,0],x[:,1], c = y_kmeans3, cmap = 'rainbow')
